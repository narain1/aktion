# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import os, operator, requests
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image

# %%
Image.open(requests.get('https://wallpapercave.com/wp/wp1827541.jpg', stream=True).raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1597x1080 at 0x23B57543B88>

# %%
def isPrime(n):
    if n < 2: return "Neither prime, nor composite"
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# returns the nth prime number
def nthPrime(n):
    numberOfPrimes = 0
    prime = 1

    while numberOfPrimes < n:
        prime += 1
        if isPrime(prime):
            numberOfPrimes += 1
    return prime

# %%
equals = operator.eq

# %%
assert equals(nthPrime(10001), 104743)
